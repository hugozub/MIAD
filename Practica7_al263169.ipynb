# %% [markdown]
# <a href="https://colab.research.google.com/github/hugozub/MIAD/blob/main/Practica7_al263169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot  as plt

# %% [markdown]
# **Instrucciones:** Carga y exploración del dataset:
#
# *   Cargar el dataset Iris utilizando seaborn o cualquier otro dataset de su elección.
# *   Verificar las primeras filas del dataset con el método .head().
#
# *   Obtener información general sobre los datos (nombres de columnas, tipos de datos, valores nulos, etc.).

# %%
df = sns.load_dataset('iris')
print(df.head(5))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Crear los siguientes gráficos con Matplotlib:
#
# **a) Gráfico de barras:**
#
# Objetivo: Comparar el promedio de largo y ancho de los pétalos entre las tres especies de Iris.
# Instrucciones: Utiliza un gráfico de barras para mostrar la media de las columnas petal_length y petal_width agrupadas por species.

# %%
media = df.groupby("species")[["petal_length", "petal_width"]].mean()
media.plot(kind="bar")

plt.title("Promedio largo y ancho de pétalos por especie")
plt.ylabel("Largo - Ancho")
plt.xlabel("Especies")
plt.show()

# %% [markdown]
# **b) Histograma:**
#
# Objetivo: Visualizar la distribución de los largos de los sépalos (sepal_length).
# Instrucciones: Crea un histograma de la variable sepal_length y asegúrate de que tenga un número adecuado de bins. Coloca etiquetas en los ejes y un título.

# %%
plt.hist(df["sepal_length"], bins=20)
plt.title("Distribución de largo de sépalos")
plt.xlabel("Largo")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# **c) Gráfico de dispersión (scatter plot):**
#
# Objetivo: Relacionar el largo del pétalo con el ancho del pétalo.
# Instrucciones: Crea un gráfico de dispersión que compare petal_length con petal_width. Usa un color diferente para cada especie.

# %%
especies = df["species"].unique()
print(especies)
diccionario = {"setosa":"purple", "versicolor":"blue","virginica":"green"}
colores = df['species'].map(diccionario)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
plt.scatter(df["petal_length"], df["petal_width"], c=colores )
plt.title("Largo vs Ancho de pétalos")
plt.xlabel("Largo")
plt.ylabel("Ancho")
plt.show()

# %% [markdown]
# **d) Gráfico de cajas (box plot):**
#
# Objetivo: Analizar la distribución de las medidas del sépalo (sepal_length, sepal_width).
# Instrucciones: Crea un gráfico de cajas para mostrar la distribución de las variables sepal_length y sepal_width por especie.

# %%
plt.boxplot([df[df["species"] == sp]["sepal_length"] for sp in df["species"].unique()], labels=df["species"].unique())
plt.boxplot([df[df["species"] == sp]["sepal_width"] for sp in df["species"].unique()], labels=df["species"].unique())

plt.title("Distribución del largo y ancho de sepas por especie")
plt.ylabel("Longitud")
plt.xlabel("Especies")
plt.show()
# Out:
# /tmp/ipython-input-3180748907.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[df["species"] == sp]["sepal_length"] for sp in df["species"].unique()], labels=df["species"].unique())
# /tmp/ipython-input-3180748907.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[df["species"] == sp]["sepal_width"] for sp in df["species"].unique()], labels=df["species"].unique())

# %% [markdown]
# **e) Gráfico de líneas:**
#
# Objetivo: Mostrar la tendencia de la longitud del pétalo (petal_length) a través de las observaciones.
# Instrucciones: Crea un gráfico de líneas utilizando la variable petal_length (en el eje Y) con el índice de las observaciones (en el eje X). Puedes hacer esto para ver cómo varía la longitud del pétalo a lo largo del dataset.

# %%
plt.plot(df["petal_length"], c="green", linestyle='dashed',
     linewidth=1)
plt.title("Largo del pétalo a través de las observaciones")
plt.xlabel("Observaciones")
plt.ylabel("Largo")
plt.show()
